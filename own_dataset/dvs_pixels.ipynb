# %%
import csv

data_x = []
data_y = []
data_time = []
data_dump = []

with open(r'/media/bru/DATA/BAG_FILES/19.01.23/data_mocap/linear/events.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        for cell in row:
            if 'x' in cell:
                data_x.append(cell.split('x:')[1].strip())
            elif 'polarity' in cell:
                data_dump.append(cell.split('polarity:')[1].strip())
            elif 'y' in cell:
                data_y.append(cell.split('y:')[1].strip())
            elif 'nsecs' in cell:
                data_dump.append(cell.split('nsecs:')[1].strip())
            elif 'secs' in cell:
                data_time.append(cell.split('secs:')[1].strip())

# Prints the data

print('x values:', data_x[0:10], len(data_x)) j
print('y values:', data_y[1000:1010], len(data_y))
print('time values:', data_time[0:10], len(data_time))
# Out:
# x values: ['318', '319', '2', '318', '318', '319', '318', '319', '318', '318'] 2175565
# ...
